# %% [markdown]
# # Ipytone: Interactive Audio in Jupyter
#
# <img src="assets/ipytone_logo_light_no_text.svg" width="200" alt="ipytone logo" />
#
# Benoît Bovy
#
# @JupyterCon Paris 2023

# %% [markdown]
# ## Hello!
#
# - I'm a freelance Earth scientist & scientific software developer
# - I'm a regular contributor to the Scientific Python ecosystem (Xarray, Fastscape)
# - I write, produce and play music (https://roscoeband.com/)
#
# <img src="assets/about-me.png" width="1000" alt="about me" />

# %% [markdown]
# ## Python / Jupyter (interactive) data visualization
#
# <br>
# <img src="assets/pyviz-libraries.png" width="1200" alt="pyviz ecosystem" />
#
# source: https://pyviz.org, Nicolas P. Rougier

# %% [markdown]
# ## What about audio?

# %% [markdown]
# Not so much beyond playing an audio file...

# %%
from IPython.display import Audio

Audio("assets/tadaa.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# <br><br>
#
# - https://github.com/victormartingarcia/sonicpi-jupyter-notebook (not Python)
# - https://github.com/nir/jupylet (also games and graphics, server-side generated audio)

# %% [markdown]
# ## Sonification
#
# *"Sonification is the use of non-speech audio to convey information or perceptualize data"*

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("ioR5np1fmEc", width=600, height=600)

# %% [markdown]
# ## Audio and music creation software
#
# <br>
# <img src="assets/audio-stack.png" width="1200" alt="audio stack" />

# %% [markdown]
# ## Ipytone

# %% [markdown]
# <br>
# <img src="assets/ipytone_logo_light.svg" width="600" alt="ipytone logo" />
#
# Many Jupyter (ipy)widgets for interactive audio and music creation.

# %% [markdown]
# ## How does it work?
#
# <br>
# <img src="assets/ipytone-arch.svg" width="1200" alt="ipytone architecture" />
