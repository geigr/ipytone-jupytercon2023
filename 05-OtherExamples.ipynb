# %% [markdown]
# # Other examples

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# ## Global CO2 concentration vs. air temperature sonification
#
# Using `bqplot`

# %%
YouTubeVideo("EGdd3wQJkHM", width=1280, height=720)

# %% [markdown]
# ## French presidential election results 2022 (1st round)
#
# Using `geopandas` and `ipyleaflet`

# %%
YouTubeVideo("1EpDZMUDR8Q", width=1280, height=720)

# %% [markdown]
# ## River meandering
#
# Using `meanderpy` and `ipycanvas`

# %%
YouTubeVideo("ygIFh0SkkU4", width=1280, height=720)
